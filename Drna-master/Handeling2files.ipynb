# %% [markdown]
# # Colab Setup

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
"""
Change directory to where this file is located
"""
# %cd '/content/drive/MyDrive/DLSP/'
# Out:
# /content/drive/MyDrive/DLSP

# %% [markdown]
# # Second Approach

# %% [markdown]
# ## Food

# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

InfoToPlot = []

for folders in os.listdir("generated_R1"):
  if folders.startswith("class_4"):
    for img in os.listdir("generated_R1" + "/"+folders):
      if img.startswith("c_4_iter_149"):
        tmp = Image.open("/content/drive/MyDrive/DLSP/"+"generated_R1" + "/"+folders+"/"+img)
        if folders.endswith("cluster_0"):
          tmp.save("./SecondApproach/Food/Cluster0/"+folders+".jpg")
        else:
          tmp.save("./SecondApproach/Food/Cluster2/"+folders+".jpg")

# %% [markdown]
# ## Medical

# %%
import os
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt

InfoToPlot = []

for folders in os.listdir("generated_R1"):
  if folders.startswith("class_7"):
    for img in os.listdir("generated_R1" + "/"+folders):
      if img.startswith("c_7_iter_149"):
        tmp = Image.open("/content/drive/MyDrive/DLSP/"+"generated_R1" + "/"+folders+"/"+img)
        if folders.endswith("cluster_1"):
          tmp.save("./SecondApproach/Medical/Cluster1/"+folders+".jpg")
        else:
          tmp.save("./SecondApproach/Medical/Cluster4/"+folders+".jpg")
